# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def sample_image(image, factor):
    height, width = image.shape[:2]
    sampled_image = cv2.resize(image, (width // factor, height // factor), interpolation=cv2.INTER_NEAREST)
    return sampled_image


def quantize_image(image, levels):
    quantized_image = np.floor(image / (256 // levels)) * (256 // levels)
    quantized_image = quantized_image.astype(np.uint8)
    return quantized_image


def plot_images(original, sampled, quantized):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.imshow(original, cmap='gray')
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(sampled, cmap='gray')
    plt.title('Sampled Image')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(quantized, cmap='gray')
    plt.title('Quantized Image')
    plt.axis('off')

    plt.show()

# %%
#task 1
image_path = '/Users/almadani/Desktop/image prosses/lab1/lena_gray_256.tif'
sampling_factor = 14
quantization_levels = 9

original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

sampled_image = sample_image(original_image, sampling_factor)
quantized_image = quantize_image(original_image, quantization_levels)

plot_images(original_image, sampled_image, quantized_image)

# %%
#task 1

image_path = '/Users/almadani/Desktop/image prosses/lab1/lena_gray_256.tif'
sampling_factor = 8
quantization_levels = 16

original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

sampled_image = sample_image(original_image, sampling_factor)
quantized_image = quantize_image(original_image, quantization_levels)

plot_images(original_image, sampled_image, quantized_image)

# %%
from PIL import Image

img1 = Image.open('/Users/almadani/Desktop/image prosses/lab1/lena_gray_256.tif')
img2 = Image.open('/Users/almadani/Desktop/image prosses/lab1/cameraman.tif')

resize = (400, 400)
img1 = img1.resize(resize, Image.Resampling.LANCZOS)
img2 = img2.resize(resize, Image.Resampling.LANCZOS)

im1arr = np.asarray(img1)
im2arr = np.asarray(img2)

addition = im1arr + im2arr
resultImage = Image.fromarray(addition)
resultImage.show()

# %%
img3 = Image.open('A.png')
img3.show()

img4 = Image.open('B.png')
img4.show()

resize = (400, 400)
img3 = img3.resize(resize, Image.Resampling.LANCZOS)
img4 = img4.resize(resize, Image.Resampling.LANCZOS)

im3arr = np.asarray(img3)
im4arr = np.asarray(img4)

union = im4arr | im3arr
resultImage2 = Image.fromarray(union)
resultImage2.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 14
#      11 im3arr = np.asarray(img3)
#      12 im4arr = np.asarray(img4)
# ---> 14 union = im4arr | im3arr
#      15 resultImage2 = Image.fromarray(union)
#      16 resultImage2.show()
#
# ValueError: operands could not be broadcast together with shapes (400,400) (400,400,4)

# %%
#task 2 part 1
add_constant = im1arr + 175
Image.fromarray(add_constant).show()

# %%
#task 2 part 2

difference = im3arr & (~im4arr)
Image.fromarray(difference).show()

# %%
#task 2 part 3


sym_diff = im3arr ^ im4arr
Image.fromarray(sym_diff).show()

# %%
#task 2 part 4


intersection = im3arr & im4arr
Image.fromarray(intersection).show()

# %%
#task 2 part 5


subtraction = im1arr - im2arr
Image.fromarray(subtraction).show()
